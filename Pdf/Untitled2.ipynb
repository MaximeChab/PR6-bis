# %%
import numpy as np

# %%
import scipy.misc

# %%
import pooch

# %%
ascent = scipy.misc.ascent()
# Out:
# /var/folders/vh/lcs4xkl560q8mp1ty5s8q3300000gn/T/ipykernel_3969/1665120508.py:1: DeprecationWarning: scipy.misc.ascent has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.ascent instead.
#   ascent = scipy.misc.ascent()

# %%
import matplotlib.pyplot as plt

# %%
plt.gray
plt.imshow(ascent)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ascent.shape
# Out:
# (512, 512)

# %%
print(ascent)
# Out:
# [[ 83  83  83 ... 117 117 117]
#  [ 82  82  83 ... 117 117 117]
#  [ 80  81  83 ... 117 117 117]
#  ...
#  [178 178 178 ...  57  59  57]
#  [178 178 178 ...  56  57  57]
#  [178 178 178 ...  57  57  58]]

# %%
zoom_ascent = ascent[270:450,140:220]

# %%
plt.imshow(zoom_ascent)
